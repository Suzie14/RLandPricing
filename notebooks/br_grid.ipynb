# %%
# %load_ext autoreload
# %autoreload 2

#.py
from core import best_response_grid as br
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       2 get_ipython().run_line_magic('autoreload', '2')
#       4 #.py
# ----> 5 from core import best_response_grid as br
#
# ModuleNotFoundError: No module named 'core'

# %% [markdown]
# # Best response grid for two players

# %%
grid = br.GridBR() #init

# %%
display(grid()[1])  #display the profits of player i 
                    #as a function of the set prices of player j (in column)
                    # and player i (in lines)
                    #underline in green the higher profit that player i can have when the price of player j is fixed
# Out:
# <style  type="text/css" >
# #T_6af7c35e_49ba_11ee_854e_406c8f513903row1_col0,#T_6af7c35e_49ba_11ee_854e_406c8f513903row1_col1,#T_6af7c35e_49ba_11ee_854e_406c8f513903row2_col2,#T_6af7c35e_49ba_11ee_854e_406c8f513903row2_col3,#T_6af7c35e_49ba_11ee_854e_406c8f513903row2_col4,#T_6af7c35e_49ba_11ee_854e_406c8f513903row3_col5,#T_6af7c35e_49ba_11ee_854e_406c8f513903row3_col6,#T_6af7c35e_49ba_11ee_854e_406c8f513903row4_col7,#T_6af7c35e_49ba_11ee_854e_406c8f513903row4_col8,#T_6af7c35e_49ba_11ee_854e_406c8f513903row5_col9,#T_6af7c35e_49ba_11ee_854e_406c8f513903row5_col10,#T_6af7c35e_49ba_11ee_854e_406c8f513903row5_col11,#T_6af7c35e_49ba_11ee_854e_406c8f513903row6_col12,#T_6af7c35e_49ba_11ee_854e_406c8f513903row6_col13,#T_6af7c35e_49ba_11ee_854e_406c8f513903row6_col14{
#             background-color:  green;
# ...

# %%
display(grid()[2])  #When player j sets the prices represented in the first array, 
                    #the second array represents the best response that player i makes 
                    # in response to player j's price choices.
# Out:
# [array([1.425     , 1.46357143, 1.50214286, 1.54071429, 1.57928571,
#         1.61785714, 1.65642857, 1.695     , 1.73357143, 1.77214286,
#         1.81071429, 1.84928571, 1.88785714, 1.92642857, 1.965     ]),
#  array([1.46357143, 1.46357143, 1.50214286, 1.50214286, 1.50214286,
#         1.54071429, 1.54071429, 1.57928571, 1.57928571, 1.61785714,
#         1.61785714, 1.61785714, 1.65642857, 1.65642857, 1.65642857])]
